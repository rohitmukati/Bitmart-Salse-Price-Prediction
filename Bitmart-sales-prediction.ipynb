# %% [markdown]
# ## importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv("Train.csv")
df_test = pd.read_csv('Test.csv')

# %%
df_train.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df_train.drop(columns=['Item_Identifier'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df_train.drop(columns=['Item_Identifier'],inplace=True)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
df_train.duplicated().sum()
# Out:
# 0

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Weight                7060 non-null   float64
#  1   Item_Fat_Content           8523 non-null   object
#  2   Item_Visibility            8523 non-null   float64
#  3   Item_Type                  8523 non-null   object
#  4   Item_MRP                   8523 non-null   float64
#  5   Outlet_Identifier          8523 non-null   object
#  6   Outlet_Establishment_Year  8523 non-null   int64
#  7   Outlet_Size                6113 non-null   object
#  8   Outlet_Location_Type       8523 non-null   object
#  9   Outlet_Type                8523 non-null   object
#  10  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 732.6+ KB

# %% [raw]
# ## item_weight , outlet_size contain missing values

# %%
df_train.isnull().sum()
# Out:
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df_train['Item_Weight'].value_counts()
# Out:
# Item_Weight
# 12.150    86
# 17.600    82
# 13.650    77
# 11.800    76
# 15.100    68
#           ..
# 7.275      2
# 7.685      1
# 9.420      1
# 6.520      1
# 5.400      1
# Name: count, Length: 415, dtype: int64

# %%
df_test.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %% [markdown]
# ## Filling missing value with mean impuation on both train and test data on column Item Weight

# %%
df_train['Item_Weight'] = df_train['Item_Weight'].fillna(df_train['Item_Weight'].mean())
df_test['Item_Weight'] = df_test['Item_Weight'].fillna(df_test['Item_Weight'].mean())

# %%
df_train.isnull().sum()
# Out:
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %% [markdown]
# ## Filling missing value with mode impuation on both train and test on column Outlet Size

# %%
df_train['Outlet_Size'] = df_train['Outlet_Size'].fillna('Medium')
df_test['Outlet_Size'] = df_test['Outlet_Size'].fillna('Medium')

# %%
df_train.isnull().sum()
# Out:
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %%
df_test.head(2)
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  Item_MRP  \
# 0        20.75          Low Fat         0.007565  Snack Foods  107.8622
# 1         8.30              reg         0.038428        Dairy   87.3198
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2007      Medium               Tier 2
#
#          Outlet_Type
# 0  Supermarket Type1
# 1  Supermarket Type1

# %%
df_train.head(2)
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  Item_MRP  \
# 0         9.30          Low Fat         0.016047        Dairy  249.8092
# 1         5.92          Regular         0.019278  Soft Drinks   48.2692
#
#   Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0            OUT049                       1999      Medium
# 1            OUT018                       2009      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1          3735.1380
# 1               Tier 3  Supermarket Type2           443.4228

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Weight                8523 non-null   float64
#  1   Item_Fat_Content           8523 non-null   object
#  2   Item_Visibility            8523 non-null   float64
#  3   Item_Type                  8523 non-null   object
#  4   Item_MRP                   8523 non-null   float64
#  5   Outlet_Identifier          8523 non-null   object
#  6   Outlet_Establishment_Year  8523 non-null   int64
#  7   Outlet_Size                8523 non-null   object
#  8   Outlet_Location_Type       8523 non-null   object
#  9   Outlet_Type                8523 non-null   object
#  10  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 732.6+ KB

# %% [markdown]
# ## Droping not essential column

# %%
df_train.drop(columns=['Outlet_Identifier'],inplace=True)
df_test.drop(columns=['Item_Identifier','Outlet_Identifier'], inplace=True)

# %%
df_train.head(1)
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility Item_Type  Item_MRP  \
# 0          9.3          Low Fat         0.016047     Dairy  249.8092
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1           3735.138

# %%
df_test.head(1)
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  Item_MRP  \
# 0        20.75          Low Fat         0.007565  Snack Foods  107.8622
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
#
#          Outlet_Type
# 0  Supermarket Type1

# %% [markdown]
# # EDA using klib library

# %% [markdown]
# ## outlier Detector

# %%
import klib

# %%
klib.cat_plot(df_train)
# Out:
# GridSpec(6, 5)

# %% [markdown]
# ## EDA

# %%
klib.corr_mat(df_train)
# Out:
# C:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\klib\describe.py:275: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   return corr.style.applymap(color_negative_red).format("{:.2f}", na_rep="-")
# <style type="text/css">
# #T_13a98_row0_col0, #T_13a98_row0_col2, #T_13a98_row0_col4, #T_13a98_row1_col1, #T_13a98_row2_col0, #T_13a98_row2_col2, #T_13a98_row2_col3, #T_13a98_row2_col4, #T_13a98_row3_col2, #T_13a98_row3_col3, #T_13a98_row4_col0, #T_13a98_row4_col2, #T_13a98_row4_col4 {
#   color: None;
# }
# #T_13a98_row0_col1, #T_13a98_row0_col3, #T_13a98_row1_col0, #T_13a98_row1_col2, #T_13a98_row1_col3, #T_13a98_row1_col4, #T_13a98_row2_col1, #T_13a98_row3_col0, #T_13a98_row3_col1, #T_13a98_row3_col4, #T_13a98_row4_col1, #T_13a98_row4_col3 {
#   color: #FF3344;
# }
# </style>
# <table id="T_13a98">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %%
klib.corr_plot(df_train)
# Out:
# <AxesSubplot: title={'center': 'Feature-correlation (pearson)'}>

# %%
df_train = klib.data_cleaning(df_train)
# Out:
# Shape of cleaned data: (8523, 10) - Remaining NAs: 0
#
#
# Dropped rows: 0
#      of which 0 duplicates. (Rows (first 150 shown): [])
#
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 0
# Reduced memory by at least: 0.46 MB (-70.77%)

# %%
df_train
# Out:
#       item_weight item_fat_content  item_visibility              item_type  \
# 0        9.300000          Low Fat         0.016047                  Dairy
# 1        5.920000          Regular         0.019278            Soft Drinks
# 2       17.500000          Low Fat         0.016760                   Meat
# 3       19.200001          Regular         0.000000  Fruits and Vegetables
# 4        8.930000          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518     6.865000          Low Fat         0.056783            Snack Foods
# 8519     8.380000          Regular         0.046982           Baking Goods
# 8520    10.600000          Low Fat         0.035186     Health and Hygiene
# 8521     7.210000          Regular         0.145221            Snack Foods
# 8522    14.800000          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
klib.clean_column_names(df_train)
# Out:
#       item_weight item_fat_content  item_visibility              item_type  \
# 0        9.300000          Low Fat         0.016047                  Dairy
# 1        5.920000          Regular         0.019278            Soft Drinks
# 2       17.500000          Low Fat         0.016760                   Meat
# 3       19.200001          Regular         0.000000  Fruits and Vegetables
# 4        8.930000          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518     6.865000          Low Fat         0.056783            Snack Foods
# 8519     8.380000          Regular         0.046982           Baking Goods
# 8520    10.600000          Low Fat         0.035186     Health and Hygiene
# 8521     7.210000          Regular         0.145221            Snack Foods
# 8522    14.800000          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   item_weight                8523 non-null   float32
#  1   item_fat_content           8523 non-null   category
#  2   item_visibility            8523 non-null   float32
#  3   item_type                  8523 non-null   category
#  4   item_mrp                   8523 non-null   float32
#  5   outlet_establishment_year  8523 non-null   int16
#  6   outlet_size                8523 non-null   category
#  7   outlet_location_type       8523 non-null   category
#  8   outlet_type                8523 non-null   category
#  9   item_outlet_sales          8523 non-null   float32
# dtypes: category(5), float32(4), int16(1)
# memory usage: 192.9 KB

# %%
klib.convert_datatypes(df_train)
# Out:
#       item_weight item_fat_content  item_visibility              item_type  \
# 0        9.300000          Low Fat         0.016047                  Dairy
# 1        5.920000          Regular         0.019278            Soft Drinks
# 2       17.500000          Low Fat         0.016760                   Meat
# 3       19.200001          Regular         0.000000  Fruits and Vegetables
# 4        8.930000          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518     6.865000          Low Fat         0.056783            Snack Foods
# 8519     8.380000          Regular         0.046982           Baking Goods
# 8520    10.600000          Low Fat         0.035186     Health and Hygiene
# 8521     7.210000          Regular         0.145221            Snack Foods
# 8522    14.800000          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
klib.drop_missing(df_train)
# Out:
#       item_weight item_fat_content  item_visibility              item_type  \
# 0        9.300000          Low Fat         0.016047                  Dairy
# 1        5.920000          Regular         0.019278            Soft Drinks
# 2       17.500000          Low Fat         0.016760                   Meat
# 3       19.200001          Regular         0.000000  Fruits and Vegetables
# 4        8.930000          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518     6.865000          Low Fat         0.056783            Snack Foods
# 8519     8.380000          Regular         0.046982           Baking Goods
# 8520    10.600000          Low Fat         0.035186     Health and Hygiene
# 8521     7.210000          Regular         0.145221            Snack Foods
# 8522    14.800000          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
klib.mv_col_handling(df_train)
# Out:
# C:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\klib\clean.py:443: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   data_local[cols_mv] = data_local[cols_mv].applymap(lambda x: x if pd.isna(x) else 1).fillna(0)
#       item_weight item_fat_content  item_visibility              item_type  \
# 0        9.300000          Low Fat         0.016047                  Dairy
# 1        5.920000          Regular         0.019278            Soft Drinks
# 2       17.500000          Low Fat         0.016760                   Meat
# 3       19.200001          Regular         0.000000  Fruits and Vegetables
# 4        8.930000          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518     6.865000          Low Fat         0.056783            Snack Foods
# 8519     8.380000          Regular         0.046982           Baking Goods
# ...

# %%
klib.pool_duplicate_subsets(df_train)
# Out:
#       item_visibility    item_mrp  item_outlet_sales  pooled_vars
# 0            0.016047  249.809204        3735.137939            0
# 1            0.019278   48.269199         443.422791            1
# 2            0.016760  141.617996        2097.270020            2
# 3            0.000000  182.095001         732.380005            3
# 4            0.000000   53.861401         994.705200            4
# ...               ...         ...                ...          ...
# 8518         0.056783  214.521805        2778.383301         8518
# 8519         0.046982  108.156998         549.284973         8519
# 8520         0.035186   85.122398        1193.113647         8520
# 8521         0.145221  103.133202        1845.597656         8521
# 8522         0.044878   75.467003         765.669983         8522
#
# [8523 rows x 4 columns]

# %% [markdown]
# # Preprocessing Task before model bulding

# %% [markdown]
# ## Encoding Categorical Columns

# %%
df_train.head(4)
# Out:
#    item_weight item_fat_content  item_visibility              item_type  \
# 0     9.300000          Low Fat         0.016047                  Dairy
# 1     5.920000          Regular         0.019278            Soft Drinks
# 2    17.500000          Low Fat         0.016760                   Meat
# 3    19.200001          Regular         0.000000  Fruits and Vegetables
#
#      item_mrp  outlet_establishment_year outlet_size outlet_location_type  \
# 0  249.809204                       1999      Medium               Tier 1
# 1   48.269199                       2009      Medium               Tier 3
# 2  141.617996                       1999      Medium               Tier 1
# 3  182.095001                       1998      Medium               Tier 3
#
#          outlet_type  item_outlet_sales
# 0  Supermarket Type1        3735.137939
# 1  Supermarket Type2         443.422791
# 2  Supermarket Type1        2097.270020
# 3      Grocery Store         732.380005

# %%
df_test
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility           Item_Type  \
# 0       20.750000          Low Fat         0.007565         Snack Foods
# 1        8.300000              reg         0.038428               Dairy
# 2       14.600000          Low Fat         0.099575              Others
# 3        7.315000          Low Fat         0.015388         Snack Foods
# 4       12.695633          Regular         0.118599               Dairy
# ...           ...              ...              ...                 ...
# 5676    10.500000          Regular         0.013496         Snack Foods
# 5677     7.600000          Regular         0.142991       Starchy Foods
# 5678    10.000000          Low Fat         0.073529  Health and Hygiene
# 5679    15.300000          Regular         0.000000              Canned
# 5680     9.500000          Regular         0.104720              Canned
#
#       Item_MRP  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# ...

# %% [markdown]
# ### 1)Label Encoding

# %%
df_test['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    3396
# Regular    1935
# LF          206
# reg          78
# low fat      66
# Name: count, dtype: int64

# %%
df_test['Item_Fat_Content'] = df_test['Item_Fat_Content'].apply(lambda x: x.replace('LF','Low Fat'))
df_test['Item_Fat_Content'] = df_test['Item_Fat_Content'].apply(lambda x: x.replace('low fat','Low Fat'))
df_test['Item_Fat_Content'] = df_test['Item_Fat_Content'].apply(lambda x: x.replace('reg','Regular'))

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df_train = df_train.apply(le.fit_transform)

# %%
df_train
# Out:
#       item_weight  item_fat_content  item_visibility  item_type  item_mrp  \
# 0             284                 0              664          4      5592
# 1              57                 1              880         14       473
# 2             376                 0              715         10      2901
# 3             393                 1                0          6      4227
# 4             265                 0                0          9       627
# ...           ...               ...              ...        ...       ...
# 8518          125                 0             3912         13      4955
# 8519          233                 1             3278          0      2023
# 8520          299                 0             2302          8      1263
# 8521          149                 1             7174         13      1857
# 8522          347                 0             3108         14      1011
#
#       outlet_establishment_year  outlet_size  outlet_location_type  \
# ...

# %%
df_test = df_train.apply(le.fit_transform)

# %%
df_test.head()
# Out:
#    item_weight  item_fat_content  item_visibility  item_type  item_mrp  \
# 0          284                 0              664          4      5592
# 1           57                 1              880         14       473
# 2          376                 0              715         10      2901
# 3          393                 1                0          6      4227
# 4          265                 0                0          9       627
#
#    outlet_establishment_year  outlet_size  outlet_location_type  outlet_type  \
# 0                          4            1                     0            1
# 1                          8            1                     2            2
# 2                          4            1                     0            1
# 3                          3            1                     2            0
# 4                          1            0                     2            1
#
#    item_outlet_sales
# 0               2540
# 1                422
# ...

# %% [markdown]
# ## Splitting Data in train and Test

# %%
from sklearn.model_selection import train_test_split

# %%
X = df_train.drop('item_outlet_sales',axis=1)

# %%
y = df_train['item_outlet_sales']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=101)

# %% [markdown]
# ## Standardization

# %%
X.describe()
# Out:
#        item_weight  item_fat_content  item_visibility    item_type  \
# count  8523.000000       8523.000000      8523.000000  8523.000000
# mean    298.756776          0.352693      3708.866127     7.226681
# std      95.451067          0.477836      2396.221439     4.209990
# min       0.000000          0.000000         0.000000     0.000000
# 25%     285.000000          0.000000      1595.500000     4.000000
# 50%     326.000000          0.000000      3708.000000     6.000000
# 75%     361.000000          1.000000      5788.500000    10.000000
# max     415.000000          1.000000      7878.000000    15.000000
#
#           item_mrp  outlet_establishment_year  outlet_size  \
# count  8523.000000                8523.000000  8523.000000
# mean   2941.096562                   3.790684     1.170832
# std    1675.483234                   2.730322     0.600327
# min       0.000000                   0.000000     0.000000
# 25%    1535.500000                   1.000000     1.000000
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
X_train_std = sc.fit_transform(X_train)

# %%
X_train_std
# Out:
# array([[ 1.00439018, -0.74155088,  0.9652137 , ..., -1.95699503,
#          1.08786619, -0.25964107],
#        [-1.23760194, -0.74155088,  0.19203621, ..., -0.28872895,
#         -0.13870429, -0.25964107],
#        [ 1.01496562,  1.34852514,  0.29176067, ..., -0.28872895,
#         -0.13870429, -0.25964107],
#        ...,
#        [ 0.23238346, -0.74155088, -1.19868187, ...,  1.37953713,
#         -1.36527477, -0.25964107],
#        [-0.09545501,  1.34852514,  1.29985393, ..., -0.28872895,
#         -0.13870429, -0.25964107],
#        [ 0.62367454, -0.74155088,  1.53977679, ..., -0.28872895,
#          1.08786619,  0.98524841]])

# %%
X_test_std = sc.transform(X_test)

# %%
X_test_std
# Out:
# array([[ 0.06317651, -0.74155088,  0.04057186, ..., -0.28872895,
#          1.08786619,  0.98524841],
#        [ 0.86690953, -0.74155088, -0.44511546, ..., -1.95699503,
#          1.08786619, -0.25964107],
#        [-1.15299846,  1.34852514,  0.48536798, ...,  1.37953713,
#         -1.36527477, -0.25964107],
#        ...,
#        [ 0.61309911, -0.74155088,  1.0849665 , ..., -0.28872895,
#          1.08786619, -1.50453056],
#        [ 0.77173062, -0.74155088, -1.55126416, ..., -0.28872895,
#          1.08786619,  0.98524841],
#        [-2.33744713,  1.34852514, -1.47240255, ..., -0.28872895,
#         -0.13870429, -0.25964107]])

# %%
y_train
# Out:
# 3684     144
# 1935    1311
# 5142    1242
# 4978    1426
# 2299    2462
#         ...
# 599     3137
# 5695    1193
# 8006    1684
# 1361    2001
# 1547     746
# Name: item_outlet_sales, Length: 6818, dtype: int64

# %%
y_test
# Out:
# 8179     801
# 8355    2056
# 3411    1529
# 7089     779
# 6954    1858
#         ...
# 1317    1386
# 4996     808
# 531      356
# 3891    1144
# 6629    1839
# Name: item_outlet_sales, Length: 1705, dtype: int64

# %% [markdown]
# ## Model Bulding

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train_std,y_train)
# Out:
# LinearRegression()

# %%
y_pred_lr = lr.predict(X_test_std)

# %%
from sklearn.metrics import r2_score, mean_absolute_error,mean_squared_error

# %%
print(r2_score(y_test,y_pred_lr))
print(mean_absolute_error(y_test,y_pred_lr))
print(mean_squared_error(y_test,y_pred_lr))
# Out:
# 0.5450221029566809
# 489.32254003413607
# 376774.49197663367

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor()

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred_rf = rf.predict(X_test)

# %%
print(r2_score(y_test,y_pred_rf))
print(mean_absolute_error(y_test,y_pred_rf))
print(np.sqrt(mean_squared_error(y_test,y_pred_rf)))
# Out:
# 0.6116484474096703
# 430.17387683284454
# 567.0980054642451

# %% [markdown]
# ## Hyper_parameter_tunning

# %%
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV

# define models and parameters
model = RandomForestRegressor()
n_estimators = [10, 100, 1000]
max_depth=range(1,31)
min_samples_leaf=np.linspace(0.1, 1.0)
max_features=["auto", "sqrt", "log2"]
min_samples_split=np.linspace(0.1, 1.0, 10)

# define grid search
grid = dict(n_estimators=n_estimators)

#cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=3, random_state=101)

grid_search_forest = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, 
                           scoring='r2',error_score=0,verbose=2,cv=2)

grid_search_forest.fit(X_train_std, y_train)

# summarize results
print(f"Best: {grid_search_forest.best_score_:.3f} using {grid_search_forest.best_params_}")
means = grid_search_forest.cv_results_['mean_test_score']
stds = grid_search_forest.cv_results_['std_test_score']
params = grid_search_forest.cv_results_['params']

for mean, stdev, param in zip(means, stds, params):
    print(f"{mean:.3f} ({stdev:.3f}) with: {param}")
# Out:
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Best: 0.621 using {'n_estimators': 1000}
# 0.589 (0.008) with: {'n_estimators': 10}
# 0.618 (0.004) with: {'n_estimators': 100}
# 0.621 (0.003) with: {'n_estimators': 1000}
